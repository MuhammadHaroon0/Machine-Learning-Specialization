# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\COURSES\\Python for Machine Learning & Data Science Masterclass\\1 - Introduction to Course\\08-Linear-Regression-Models\\Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend']=df['TV']+df['newspaper']+df['radio']

# %%
X=df['total_spend']
y=df['sales']

# %%
sns.scatterplot(data=df,x=X,y=y)
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
sns.regplot(data=df,x=X,y=y)
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
np.polyfit(X,y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
#B1-->slope B0-->intercept
tot_spend=200

pred_sales= 0.04868788*tot_spend+4.24302822
pred_sales
# Out:
# 13.98060422

# %%
x=np.linspace(0,500,100)
y=0.04868788*x+4.24302822

# %%
sns.scatterplot(data=df,x='total_spend',y='sales')
plt.plot(x,y,c='r')

# %%
X=df['total_spend']
y=df['sales']
np.polyfit(X,y,deg=3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
new_spend=np.linspace(0,500,100)

new_sales=3.07615033e-07*new_spend**3 +-1.89392449e-04*new_spend**2  +8.20886302e-02*new_spend  +2.70495053e+00

# %%
sns.scatterplot(data=df,x=X,y=y)
plt.plot(new_spend,new_sales,c='r')
