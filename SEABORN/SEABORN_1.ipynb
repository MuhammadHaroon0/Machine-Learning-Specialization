# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\COURSES\\Python for Machine Learning & Data Science Masterclass\\1 - Introduction to Course\\05-Seaborn\\dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",hue="level of education")
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",style="level of education")
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",hue="salary")
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",hue="salary",palette="plasma")
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",size='level of education',alpha=0.4)
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",s=90,alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x="salary",y="sales",style="level of education",hue="level of education",s=70)
plt.savefig('D:\CS\SIDE SKILLS\MACHINE LEARNING\ML SPECIALIZATION\SEABORN\\seabornscatter.jpg')
plt.show()

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
sns.rugplot(data=df,x="salary",height=0.5)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.set(style='darkgrid')
sns.displot(data=df,x="salary",kde=True,rug=True,color='r',edgecolor='b',lw=4,ls='--',bins=15)

# %%
sns.kdeplot(data=df,x="salary")
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
np.random.seed(32)
newdf=pd.DataFrame(np.random.randint(0,100,200),columns=['age'])

# %%
sns.displot(data=newdf,x="age",kde=True,rug=True,color='r',edgecolor='b',lw=4,bins=15)

# %%
sns.kdeplot(data=newdf,x="age",clip=[0,100] ,bw_adjust=0.6,fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(10,5),dpi=200)

sns.countplot(data=df,x="level of education")
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,5),dpi=200)

sns.countplot(data=df,x="level of education",hue='division',palette="plasma")
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
df['level of education'].value_counts()
# Out:
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: level of education, dtype: int64

# %%
plt.figure(figsize=(10,5),dpi=200)

sns.barplot(data=df,x="level of education",y='salary',estimator=np.mean,ci='sd',hue='division')
# plt.legend(bbox_to_anchor=(1.05,1))
plt.legend(loc=(1.1,0))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14768\3609972622.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df,x="level of education",y='salary',estimator=np.mean,ci='sd',hue='division')
