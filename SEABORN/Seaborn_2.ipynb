# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df=pd.read_csv("D:\\COURSES\\Python for Machine Learning & Data Science Masterclass\\1 - Introduction to Course\\05-Seaborn\\StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
 sns.jointplot(df,x="math score",y='reading score',kind="hex",color='r')  #darker the hexagon  greater the points there

# %%
 sns.jointplot(df,x="math score",y='reading score',kind="hist",color='r')  #darker the hexagon  greater the points there

# %%
sns.jointplot(df,x="math score",y='reading score',kind="hex",alpha=0.6)

# %%
sns.jointplot(df,x="math score",y='reading score',kind="scatter",hue='gender')

# %%
sns.jointplot(df,x="math score",y='reading score',kind="kde",fill=True)

# %%
sns.pairplot(df,hue="gender",kind="kde")

# %%
sns.pairplot(df,hue="gender",corner=True)

# %%
sns.pairplot(df,hue="gender",kind="kde",diag_kind='hist')

# %%
sns.catplot(df,x="gender",y="reading score",kind="box",row="lunch",col="race/ethnicity",hue="test preparation course")

# %%
sns.PairGrid(df)

# %%
g=sns.PairGrid(df,hue='gender')
g=g.map_upper(sns.scatterplot)
g=g.map_diag(sns.histplot)

g=g.map_lower(sns.kdeplot)

# %%
df=df=pd.read_csv("D:\\COURSES\\Python for Machine Learning & Data Science Masterclass\\1 - Introduction to Course\\05-Seaborn\\country_table.csv")

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df=df.drop('Life expectancy',axis=1)

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Infant mortality rate  Growth rate
# 0                 44.215        24.40
# 1                 23.185         8.44
# 2                  3.750         0.38
# 3                 14.570         8.89
# 4                  5.563         6.11
# 5                 16.939        12.79
# 6                 27.492        10.36

# %%
sns.heatmap(data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sns.heatmap(data=df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
df=df.set_index('Countries')

# %%
sns.heatmap(data=df)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(data=df,cmap='viridis',lw=0.4,annot=True)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.clustermap(data=df,cmap='viridis',lw=0.4,annot=True)

# %%
sns.clustermap(data=df,cmap='viridis',lw=0.4,annot=True,col_cluster=False)
